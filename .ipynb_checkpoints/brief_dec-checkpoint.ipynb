# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import GammaRegressor 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import PowerTransformer
from numpy.random import randn
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from numpy import sqrt
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.cluster import DBSCAN
from scipy.stats import gaussian_kde

#library to create the pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn import set_config
import patsy
import patsylearn

from sklearn.base import BaseEstimator, TransformerMixin
#see parsytransformer.py
from my_transformers import FormulaTransformer
from my_transformers import NoTransformer
from my_transformers import Float16Transformer
from my_transformers import DFTransformer
from my_transformers import ColNameTransformer

#to save and load the pipeline and model fitted in a pickle (.pkl) file
import pickle
import patsy

#import geocoder
#from geopy.geocoders import GoogleV3

# %%
df_original = pd.read_csv('housing.csv')

# %%
df_original.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df_original.shape
# Out:
# (20640, 10)

# %% [markdown]
# <h1>Choix du dataset et brief descriptif:</h1>
#
# Le dataset choisi sur le site Kaggle ("California Housing Prices") porte sur des données immobilières collectées dans les années 90 et couvre l'ensemble de l'état de Californie.
#
# Le dataset reporte:
#
# -la géolocalisation du district (latitude & longitude)
# -housing_median_age = age médian des ménages
# -total_rooms = nombre total de pièces dans le district
# -total_bedrooms = nombre total de chambres
# -population
# -households = nombre de ménages
# -médian_income = revenue médian
# -médian_house_value = prix médian des maisons
# -ocean_proximity = la proximity du district avec l'océan avec 5 catégories ('<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'NEAR BAY', 'ISLAND')
#
# Le dataset possède 10 colonnes et 20640 lignes

# %% [markdown]
# <h2>Objectifs principaux:</h2>
#
# -Réaliser un modèle permettant de prédire le prix médian des maisons d'un district.
# -Réaliser une API utilisant ce modèle et renvoyant la prédiction.
#
# <h2>Objectifs annexes (pour le fun):</h2>
#
# -Créer une feature catégorielle de type code postal à partir des coordonnées de géolocalisation
# -Présenter des données sur une carte (géovisualisation)
# -Utiliser les formules de modèle de type R afin de créer des matrices utilisables dans sklearn, et surtout implémenter l'approche dans un pipeline avec les attributs .fit, .transform, .predict.
#
# C'est parti!!!

# %% [markdown]
# <h1>Data cleaning and feature engineering</h1>

# %% [markdown]
# <h2>Création d'une feature catégorielle de type code postal/zip code à partir des coordonnées de géolocalisation</h2>
#
# Le but est ici de recupérer via l'API de géolocalisation de google map les addresses correspondant aux coordonnées pour chaque points du dataset en itérant sur le pd.DataFrame. Un compte a été créer à cet effet afin de récupérer une api_key. Google autorise 40000 requettes par mois sans frais pour cette API.
# Les données JSON ont été converti en string puis stocké dans un dictionnaire, la clé correspondant à l'index du dataset. Le dictionnaire a ensuite été converti en pd.DataFrame et la colonne d'intéret ajouter au dataset, puis sauvagardé au format .csv

# %%
#from geopy.geocoders import GoogleV3

#google_key = "my_api_key"
#geolocator = GoogleV3(api_key = google_key)

#dict_geoloc = {}

#for i in range(0, len(X.index)):
#    lat = X['latitude'][i]
#    long = X['longitude'][i]
#    coordinates = f"{lat}, {long}"
#    locations = geolocator.reverse(coordinates)
#    address = str(locations)
#    dict_geoloc[i] = address  
#dict_geoloc_pd = pd.DataFrame.from_dict(dict_geoloc, orient = 'index')
#df['addresses'] = dict_geoloc_pd[0]
#df.to_csv('housing_geoloc.csv')

# %% [markdown]
# <h2>Visualisation des données quantitatives (hist)</h2>
#
# -On note que la distribution des données est de manière générale biaisée vers la gauche
#
# -On note aussi que certaines variables possèdent des distributions abérrantes de variables dans leurs limites supérieurs. Par exemple, median_hous_value plafonne à 500 000 dollars, valeur pour laquelle un très grand nombre de ligne (5% environ) sont représentées. Les valeurs supérieurs ont donc été tronquées à 500 000 dollars, et ces lignes ne seront donc pas utilisables dans le cadre d'une approche par régression linéaire. La même observation est faites pour les variables median_income et housing_mean_age.
#
# -Concernant la variable catégorielle ocean_proximity, la classe ISLAND n'est représenté que 5 fois sur 20000... les lignes correspondantes devront être supprimées ou requalifiées si utilisées ultérieurement au sein du modèle.

# %%
#Reload de dataset with the 'addresses' colonne
df = pd.read_csv('housing_geoloc.csv')
df = pd.DataFrame(df)
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
#
#                                          addresses
# 0  3126 Grizzly Peak Blvd, Berkeley, CA 94705, USA

# %%
df.hist(bins = 100, figsize = (10,10))
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %% [markdown]
# Le code suivant à pour objectif d'extraire le ZIP code de l'adresse.
#
# La démarche et la suivante:
# <ul><li>La string de l'adresse est transformée en liste (.split())</li>
# <li>Les longueurs des listes sont évaluée</li>
# <li>Les lignes pour lesquelles la longueur est inférieurs à 2 sont supprimées, car elles ne contiennent pas de ZIP code</li>
# <li>L'avant-dernier élément de chaque listes (str) est copier dans une nouvelle colonne >>> str de type 'CA 92506'</li>
# <li>La ville est aussi récupérer >>> antépénultième élément de chaque liste</li>
# <li>Le 'CA' est supprimé de la strip afin de récupérer uniquement le ZIP code</li>
# <li>Les lignes dans lesquelles le zip code est vide sont supprimées</li>
# <li>Uniquement les cinqs derriers éléments de chaque ZIP code sont sélectionnées dans le doute</li>
# <li>Les lignes n'ayant pas de ZIP code commencant par 9 sont supprimées</li>
# <li>Des ZIP codes simplifiés sont créés en ne retenant que les deux ou trois premiers numéro du code afin de diminuer le nombre de classes de ZIP</li>
# </ul>

# %%
df.shape[0]
# Out:
# 20640

# %%
df['list_adresses'] = df['addresses'].apply(lambda x: x.split(','))
df['len_list_adresses'] = df['list_adresses'].apply(lambda x: len(x))
df = df[df['len_list_adresses'] > 2]
df['zip_code'] = df['list_adresses'].apply(lambda x: x[-2].replace('CA', '').strip())
df['city'] = df['list_adresses'].apply(lambda x: x[-3])
df = df[df['zip_code'] != '']
df['zip_code'] = df['zip_code'].apply(lambda x: x[-5:])
df['zip_code'] = df['zip_code'].apply(lambda x: x if x[0] == '9' else 'NA')
df = df[df['zip_code'] != 'NA']
df['zip_simplified'] = df['zip_code'].apply(lambda x: x[0:-2])
df['zip_simplified2'] = df['zip_code'].apply(lambda x: x[0:-3])


a = df['zip_simplified'].value_counts().reset_index()
a = pd.DataFrame(a)
dict ={}
for i in range(len(a['index'])):
    dict[a['index'].iloc[i]] = a['zip_simplified'].iloc[i]
df['zip_simp_numb'] = df['zip_simplified'].apply(lambda x: dict[x])
#df = df[df['zip_simp_numb'] > 50]

# %%
(20640 - df.shape[0])/20640
# Out:
# 0.1186046511627907

# %% [markdown]
# <ul>
# <li>2448 lignes sont supprimés car elle ne contiennent pas de données ZIP code valides pour l'état de Californie (environ 12% des données)</li>
# <li>les données supérieurs tronquées sont supprimés ainsi que la classe ISLAND</li>
# <li>une variable pop_per_rooms est créer afin de refléter la demande immobilière (une valeur extrême est supprimée, 1450 personnes par pièces!)</li>
# <li>les colonnnes inutiles sont supprimées</li>
# </ul>

# %%
df = df[df['median_house_value'] < 499000]
df = df[df['housing_median_age'] < 52]
df = df[df['median_income'] < 15.0001]
#df = df[df['total_rooms'] > 500]
#df = df.drop(columns = ['longitude', 'latitude', 'population','addresses', 'housing_median_age','total_bedrooms', 'list_adresses', 'len_list_adresses', 'zip_code', 'city', 'zip_simplified'])
df['pop_per_rooms'] = df['population']/df['total_rooms']
df = df[df['pop_per_rooms'] < 50]
df = df[df['ocean_proximity'] != 'ISLAND']
df = df.drop(columns = ['longitude', 'latitude', 'addresses', 'list_adresses', 'len_list_adresses', 'zip_code', 'city', 'zip_simp_numb'])

# %%
(20640 - df.shape[0])/20640
# Out:
# 0.21090116279069768

# %% [markdown]
# <ul>
# <li>nous avons perdu environ 21% des lignes du dataset à ce stade</li>
#     <li>mais le dataset est maintenant "propre"</li>
# </ul>

# %%
df.hist(bins = 100, figsize = (10,10))
# Out:
# array([[<AxesSubplot:title={'center':'housing_median_age'}>,
#         <AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>],
#        [<AxesSubplot:title={'center':'population'}>,
#         <AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>],
#        [<AxesSubplot:title={'center':'median_house_value'}>,
#         <AxesSubplot:title={'center':'pop_per_rooms'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# <h1>Choix des paramètres du modèle</h1>
# <ul>
# <li>Un petit seaborn.pairplot() s'impose afin de visualiser la meilleur feature pour expliquer le median_house_value</li>
# </ul>

# %%
g = sns.pairplot(df, hue = 'zip_simplified', plot_kws={'alpha':0.1})
g._legend.remove()

# %%
#formula = 'median_house_value ~ households * total_rooms * population * housing_median_age * median_income * zip_simplified2'
#formula = 'housing_median_age * total_rooms * population * households *median_income *  ocean_proximity * zip_simplified2'
formula = 'pop_per_rooms * median_income * zip_simplified'
#formula = 'median_house_value ~ housing_median_age * total_rooms * population * households * median_income * zip_simplified2'
col_names = df.columns

# %%
X = df.drop(columns=['median_house_value'])
y = df['median_house_value']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7)
col_names = X.columns

# %% [markdown]
# Finding the best alpha for Ridge Regression

# %%
num_pipeline = Pipeline([
    ('simple_imp', SimpleImputer(strategy="mean")),
    ('pt', PowerTransformer())
    ])

preprocessor = ColumnTransformer([('num_transform', num_pipeline, ['pop_per_rooms', 'median_income']),
                                ('NoTransformer', NoTransformer(), ['zip_simplified']),
                                ])

workflow = make_pipeline(preprocessor, 
                         DFTransformer(),
                         ColNameTransformer(),
                         Float16Transformer(),
                         patsylearn.my_transformers(formula),
                         )

set_config(display="diagram")

workflow
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_transform',
#                                                   Pipeline(steps=[('simple_imp',
#                                                                    SimpleImputer()),
#                                                                   ('pt',
#                                                                    PowerTransformer())]),
#                                                   ['pop_per_rooms',
#                                                    'median_income']),
#                                                  ('NoTransformer',
#                                                   NoTransformer(),
#                                                   ['zip_simplified'])])),
#                 ('dftransformer', DFTransformer()),
#                 ('colnametransformer', ColNameTransformer()),
#                 ('float16transformer', Float16Transformer()),
# ...

# %%
workflow.fit(X_train)
X_train = workflow.transform(X_train)

# %%
regr_cv = RidgeCV(alphas=[i/10 for i in range(1, 10, 1)])
model_cv = regr_cv.fit(X_train, y_train)

# %%
model_cv.alpha_
# Out:
# 0.9

# %% [markdown]
# Ftting the model with the best alpha found

# %%
X = df.drop(columns=['median_house_value'])
y = df['median_house_value']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7)
col_names = X.columns

# %%
num_pipeline = Pipeline([
    ('simple_imp', SimpleImputer(strategy="mean")),
    ('pt', PowerTransformer())
    ])

preprocessor = ColumnTransformer([('num_transform', num_pipeline, ['pop_per_rooms', 'median_income']),
                                ('NoTransformer', NoTransformer(), ['zip_simplified']),
                                ])

workflow = make_pipeline(preprocessor, 
                         DFTransformer(),
                         ColNameTransformer(),
                         Float16Transformer(),
                         patsylearn.my_transformers(formula),
                         Ridge(alpha = 0.9, fit_intercept = False))

set_config(display="diagram")

workflow
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_transform',
#                                                   Pipeline(steps=[('simple_imp',
#                                                                    SimpleImputer()),
#                                                                   ('pt',
#                                                                    PowerTransformer())]),
#                                                   ['pop_per_rooms',
#                                                    'median_income']),
#                                                  ('NoTransformer',
#                                                   NoTransformer(),
#                                                   ['zip_simplified'])])),
#                 ('dftransformer', DFTransformer()),
#                 ('colnametransformer', ColNameTransformer()),
#                 ('float16transformer', Float16Transformer()),
# ...

# %%
workflow.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_transform',
#                                                   Pipeline(steps=[('simple_imp',
#                                                                    SimpleImputer()),
#                                                                   ('pt',
#                                                                    PowerTransformer())]),
#                                                   ['pop_per_rooms',
#                                                    'median_income']),
#                                                  ('NoTransformer',
#                                                   NoTransformer(),
#                                                   ['zip_simplified'])])),
#                 ('dftransformer', DFTransformer()),
#                 ('colnametransformer', ColNameTransformer()),
#                 ('float16transformer', Float16Transformer()),
# ...

# %%
workflow.score(X_test, y_test)
# Out:
# 0.7134329729580045

# %%
cv_results = cross_validate(workflow, X_train, y_train, cv=5)

# %%
cv_results
# Out:
# {'fit_time': array([0.09730721, 0.11300516, 0.08071232, 0.06989646, 0.08481598]),
#  'score_time': array([0.0453651 , 0.04174161, 0.01830959, 0.02034307, 0.04453087]),
#  'test_score': array([0.72691156, 0.72342526, 0.74279408, 0.7474681 , 0.71623247])}

# %%
pred = workflow.predict(X)

# %%
X['pred'] = pred

# %%
min = X[X['pred'] == X['pred'].min()]

# %%
min

# %%
xy = np.vstack([y,pred])
z = gaussian_kde(xy)(xy)

plt.figure(figsize = (8,8))
plt.scatter(y,pred, alpha = 0.1, c = z, label = 'median_house_value')
plt.plot([0,500000],[0,500000], c ='r', label = '1:1 line')
plt.xlabel('Observed median_house_value in US dollar')
plt.ylabel('Predicted median_house_value in US dollar')
plt.legend()

# %%
plt.figure(figsize = (10,10))
plt.scatter(y_test,pred, alpha = 0.1)
plt.plot([0,500000],[0,500000], c ='r')

# %%
regr_cv = RidgeCV(alphas=[0.1, 1.0, 10.0])
model_cv = regr_cv.fit(X_train, y_train)

# %%
res = y_test-pred

# %%
res = pd.DataFrame(res)

# %%
res.hist(bins = 100)

# %%
sm.qqplot(res)

# %%
X

# %%
X = pd.DataFrame(X, columns = col_names)

# %%
X[['housing_median_age', 'total_rooms', 'population', 'households',
       'median_income']] = X[['housing_median_age', 'total_rooms', 'population', 'households',
       'median_income']].astype(np.float16)

# %%
patsyfied = patsylearn.my_transformers(formula)

# %%
patsyfied.fit(X)

# %%
X = patsyfied.transform(X)

# %%
X

# %%
lm = Ridge()

# %%
lm.fit(X, y)

# %%
lm.score(X, y)

# %%
model = smf.ols(formula, data=df).fit_regularized(L1_wt = 0, profile_scale = True, refit = True)

# %%
model = smf.ols(formula, data=df).fit()

# %%
patsyfied = patsylearn.my_transformers('households * total_rooms * housing_median_age * median_income * zip_simplified2')

# %%
patsyfied = FormulaTransformer(formula)

# %%
patsyfied.fit(X)

# %%
X = patsyfied.transform(X)

# %%
X = pd.DataFrame(X)

# %%
X.head()

# %%
set_config(display="diagram")

# %%
#create the diagram of the pipeline
pipeline_workflow

# %%
#Now we can fit the pipeline_workflow with the train data
#The object pipeline_workflow is modified with the parameters of the model being added 
pipeline_workflow.fit(X_train, y_train)

# %%
pipeline_workflow

# %%
pipeline_workflow.score(X_train, y_train)

# %%
df.shape

# %%
df.isna().any()

# %%
df = df.drop(columns = ['list_adresses'])

# %%
df.duplicated().any()

# %%
df['zip_simplified2'].value_counts()

# %%
df

# %%
df.count()/df.shape[0]

# %%
df_city_list = df['city'].value_counts()
df_city_list = pd.DataFrame(df_city_list)
df_city_list1 = df_city_list[df_city_list['city'] == 1]

# %%
df_city_list1

# %%
X = df[['latitude','longitude']]

# %%
df.to_csv('housing_geoloc.csv')

# %%
dict_geoloc_pd.to_csv('geoloc.csv')

# %%
sns.lmplot('latitude', 'longitude', df)

# %%
X = df[['latitude','longitude']]

# %%
clustering = DBSCAN(eps=0.15, min_samples=2).fit(X)
clust = clustering.labels_

# %%
X['clust'] = clust
X['clust'].value_counts()
#X['clust'].unique()

# %%
sns.lmplot('latitude', 'longitude', X, hue = 'clust')

# %%
df['clust'] = X['clust'].astype(str)

# %%
df.head()

# %%
#model = smf.ols('median_house_value ~ households * total_rooms * population * housing_median_age * median_income * ocean_proximity * zip_simplified2', data=df).fit_regularized(L1_wt = 0)

#model = smf.ols('median_house_value ~ households * total_rooms * population * housing_median_age * median_income * zip_simplified2', data=df).fit_regularized(L1_wt = 0, profile_scale = True, refit = True)
#model = smf.ols('median_house_value ~ households * total_rooms * population * housing_median_age * median_income * latitude * longitude', data=df).fit_regularized(L1_wt = 0, profile_scale = True, refit = True)
model = smf.ols('median_house_value ~ households + total_rooms + population + housing_median_age + median_income + latitude + longitude', data=df).fit_regularized(L1_wt = 0, profile_scale = True, refit = True)

#model = smf.ols('median_house_value ~ households * total_rooms * population * housing_median_age * median_income * ocean_proximity', data=df).fit_regularized()
#sm.stats.anova_lm(model, typ=2)

# %%
#model.summary()
model.params

# %%
model.score(df)

# %%
pred = model.predict(df)

# %%
df['pred'] = pred

# %%
from sklearn.metrics import r2_score
r2_score(df['median_house_value'],df['pred'])

# %%
df = df[df['pred'] < 499000]
df = df[df['pred'] > 0]

# %%
sns.lmplot('median_house_value','pred', df, scatter_kws={'s':20,'alpha':0.2})

# %%
plt.figure(figsize = (10,10))
plt.scatter(df['median_house_value'],df['pred'], alpha = 0.1)
plt.plot([0,500000],[0,500000], c ='r')

# %%
df.head(2)

# %%
print(g.county)

# %%
df = pd.read_csv('housing.csv')

# %%
df.shape

# %%
df.count()/df.shape[0]

# %%
df = df.dropna()

# %%
df_sub = df.sample(frac=0.2, replace=True, random_state=1)
df_sub = df_sub.reset_index()
df_sub = df_sub.drop(columns = ['index'])

# %%
df_sub.head()

# %%
sns.pairplot(df_sub, hue = 'ocean_proximity')

# %%
X = df.drop(columns=['median_house_value'])
y = df['median_house_value']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7)

# %%
geo1 = pd.read_csv('geoloc.csv')
geo2 = pd.read_csv('geoloc2.csv')

# %%
geo1

# %%
geo3

# %%
geo3 = {}

for i in geo1['Unnamed: 0']:
    geo3[i] = geo1['0'].iloc[i]

# %%
geo2

# %%
for i in geo2.index:
    geo3[geo2['Unnamed: 0'].iloc[i]] = geo2['0'].iloc[i]

# %%
geo3_df = pd.DataFrame.from_dict(geo3, orient = 'index')
geo3_df.to_csv('geoloc_full.csv')

# %%
df['addresses'] = geo3_df[0]

# %%
df

# %%
geo3_df[0]

# %%
#imputer replace the missing values using a given strategie, here the median
#Pipeline() take a list of 2D tuple (2 parameters > ('name given to the step in the pipeline', the Class to instanced at this step)).   
#the object num_pipeline is than instanced as a Class Pipeline()
#which make 'imputer' and 'minmax_scaler' act in SERIE  
num_pipeline = Pipeline([
    ('simple_imp', SimpleImputer(strategy="median")),
    ('pt', PowerTransformer(standardize = True))
])

# %%
#Instance a object preprocessor using the Class ColumnTransformer
#Take a list of 3D tuple ("given name of the step", name of object instance for stuff to does in differents columns, ["name of column",..., "name of column"]) 
#Will make the Object num_pipeline et cat_transformer run in PARALLEL on given columns specified
preprocessor = ColumnTransformer([('num_transformer', num_pipeline, ['housing_median_age', 'total_rooms','total_bedrooms', 'population', 'households', 'median_income', 'pop_per_bedrooms', 'pop_per_rooms'])])

# %%
pipeline_workflow = make_pipeline(preprocessor, LinearRegression())

# %%
set_config(display="diagram")

# %%
#make the pipeline with the Object preprocessor and a LinearRegression (will instance the object preprocess with Class LinearRegression)
pipeline_workflow = make_pipeline(preprocessor, smf.ols())

# %%
#create the diagram of the pipeline
pipeline_workflow

# %%
#Now we can fit the pipeline_workflow with the train data
#The object pipeline_workflow is modified with the parameters of the model being added 
pipeline_workflow.fit(X_train, y_train)

# %%
#Now we score on the test data
pipeline_workflow.score(X_test, y_test)

# %%
#We can predict on the X_test if needed
pred = pipeline_workflow.predict(X_test)
pred

# %%
#Now we have fit the model with the pipeline with the whole dataset
#This will modified the pipeline_workflow object again, with new model parameters
pipeline_workflow.fit(X, y)
